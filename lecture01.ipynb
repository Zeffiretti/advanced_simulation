# %%
print("hello world")
# Out:
# hello world

# %%
import taichi as ti
ti.init(arch=ti.gpu)
# Out:
# [Taichi] mode=release
# [Taichi] version 0.7.20, llvm 10.0.0, commit 284f75ed, win, python 3.8.10
# [Taichi] Starting on arch=cuda

# %%
a=ti.var(dt=ti.f32,shape=(42,63))
b=ti.Vector(3,dt=ti.f32,shape=4)
C=ti.Matrix(2,2,dt=ti.f32,shape=(5,5))

loss=ti.var(dt=ti.f32,shape=())

a[3,4]=1
print("a[3,4] = ", a[3,4])

b[2]=[6,7,8]
print("b[0] = ", b[0][0], b[0][1], b[0][2])

loss[None]=3
print(loss[None])
# Out:
# DeprecationWarning: ti.var is deprecated. Please use ti.field instead.
#
#   File "c:\Users\zeffi\.vscode\extensions\ms-toolsai.jupyter-2021.6.832593372\pythonFiles\vscode_datascience_helpers\..\pyvsc-run-isolated.py", line 30, in <module>
#     runpy.run_path(module, run_name="__main__")
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 265, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\zeffi\.vscode\extensions\ms-toolsai.jupyter-2021.6.832593372\pythonFiles\vscode_datascience_helpers\kernel_prewarm_starter.py", line 31, in <module>
#     runpy.run_module(module, run_name="__main__", alter_sys=False)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 210, in run_module
#     return _run_code(code, {}, init_globals, run_name, mod_spec)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-299d1a256dcc>", line 1, in <module>
#     a=ti.var(dt=ti.f32,shape=(42,63))
#
# DeprecationWarning: Declaring global matrices using `ti.Matrix(n, m, dt, shape)` is deprecated, use `ti.Matrix.field(n, m, dtype, shape)` instead
#
#   File "c:\Users\zeffi\.vscode\extensions\ms-toolsai.jupyter-2021.6.832593372\pythonFiles\vscode_datascience_helpers\..\pyvsc-run-isolated.py", line 30, in <module>
#     runpy.run_path(module, run_name="__main__")
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 265, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\zeffi\.vscode\extensions\ms-toolsai.jupyter-2021.6.832593372\pythonFiles\vscode_datascience_helpers\kernel_prewarm_starter.py", line 31, in <module>
#     runpy.run_module(module, run_name="__main__", alter_sys=False)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 210, in run_module
#     return _run_code(code, {}, init_globals, run_name, mod_spec)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-299d1a256dcc>", line 2, in <module>
#     b=ti.Vector(3,dt=ti.f32,shape=4)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\taichi\lang\matrix.py", line 994, in Vector
#     return Matrix(n, 1, dt=dt, shape=shape, offset=offset, **kwargs)
#
# DeprecationWarning: Declaring global matrices using `ti.Matrix(n, m, dt, shape)` is deprecated, use `ti.Matrix.field(n, m, dtype, shape)` instead
#
#   File "c:\Users\zeffi\.vscode\extensions\ms-toolsai.jupyter-2021.6.832593372\pythonFiles\vscode_datascience_helpers\..\pyvsc-run-isolated.py", line 30, in <module>
#     runpy.run_path(module, run_name="__main__")
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 265, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\zeffi\.vscode\extensions\ms-toolsai.jupyter-2021.6.832593372\pythonFiles\vscode_datascience_helpers\kernel_prewarm_starter.py", line 31, in <module>
#     runpy.run_module(module, run_name="__main__", alter_sys=False)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 210, in run_module
#     return _run_code(code, {}, init_globals, run_name, mod_spec)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-299d1a256dcc>", line 3, in <module>
#     C=ti.Matrix(2,2,dt=ti.f32,shape=(5,5))
#
# DeprecationWarning: ti.var is deprecated. Please use ti.field instead.
#
#   File "c:\Users\zeffi\.vscode\extensions\ms-toolsai.jupyter-2021.6.832593372\pythonFiles\vscode_datascience_helpers\..\pyvsc-run-isolated.py", line 30, in <module>
#     runpy.run_path(module, run_name="__main__")
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 265, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\zeffi\.vscode\extensions\ms-toolsai.jupyter-2021.6.832593372\pythonFiles\vscode_datascience_helpers\kernel_prewarm_starter.py", line 31, in <module>
#     runpy.run_module(module, run_name="__main__", alter_sys=False)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 210, in run_module
#     return _run_code(code, {}, init_globals, run_name, mod_spec)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "D:\Apps\Anaconda3\envs\taichi\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-299d1a256dcc>", line 5, in <module>
#     loss=ti.var(dt=ti.f32,shape=())
#
# [Taichi] materializing...
# a[3,4] =  1.0
# b[0] =  0.0 0.0 0.0
# 3.0
